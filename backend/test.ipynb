# %%
from app.nlp.loaders.gyoyuk_loader import load_gyoyuk_json

# ✅ JSON 파일 경로 지정
json_path = "C:/Users/rmawl/Desktop/chatbotData/교육과정_JSON/2025_교육과정.json"  # 실제 경로 입력

# ✅ 데이터 로드
docs = load_gyoyuk_json(json_path)
print(f"총 {len(docs)}개의 Document 로드 완료")
# Out:
# 총 2536개의 Document 로드 완료

# %%
for doc in docs:
    doc.metadata["category"] = "gyoyuk"
print("✅ category='gyoyuk' 메타데이터 추가 완료")
# Out:
# ✅ category='gyoyuk' 메타데이터 추가 완료

# %%
for i, doc in enumerate(docs[:5]):  # 앞 5개만 확인
    print(f"\n--- Document {i+1} ---")
    print(f"page_content:\n{doc.page_content}")
    print(f"metadata:\n{doc.metadata}")
# Out:
# --- Document 1 ---
# page_content:
# 2025학년도 본부직속 자유전공학부(인문사회.자연)  1학년 1학기 전공선택 과목 '전공 탐색' (LS0601), 2학점, 과정유형: 전공-전공선택
# metadata:
# {'year': '2025', 'college': '본부직속', 'department': '자유전공학부(인문사회.자연)', 'major': '', 'grade': '1', 'semester': '1', 'requirement': '전공선택', 'course_code': 'LS0601', 'course_name': '전공 탐색', 'credit': '2', 'curriculum_type': '전공-전공선택', 'category': 'gyoyuk'}
#
# --- Document 2 ---
# page_content:
# 2025학년도 본부직속 자유전공학부(인문사회.자연)  1학년 2학기 전공선택 과목 '주제 탐구와 설계' (LS0602), 2학점, 과정유형: 전공-전공선택
# metadata:
# {'year': '2025', 'college': '본부직속', 'department': '자유전공학부(인문사회.자연)', 'major': '', 'grade': '1', 'semester': '2', 'requirement': '전공선택', 'course_code': 'LS0602', 'course_name': '주제 탐구와 설계', 'credit': '2', 'curriculum_type': '전공-전공선택', 'category': 'gyoyuk'}
#
# --- Document 3 ---
# page_content:
# 2025학년도 본부직속 스마트팩토리혁신학과  3학년 1학기 전공선택 과목 '스마트기능성소재공학' (SF0657), 3학점, 과정유형: 전공-전공선택
# metadata:
# ...
